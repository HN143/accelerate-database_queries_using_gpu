# %%
import pandas as pd
from datetime import datetime, timedelta
import os  # Add this import
# Load CSV files
data = pd.read_csv('tpc-h/2gb/run3/query_execution_times.csv')
data1 = pd.read_csv('tpc-h/2gb/run3/query2_execution_times.csv')
filename = 'query_metrics_worst_case_run3.csv'
query=99

if os.path.exists(filename):
    print(f"Found existing {filename}, removing it...")
    os.remove(filename)
# Clean column names
data.columns = data.columns.str.strip()
data1.columns = data1.columns.str.strip()

# Clean the timestamp strings in data1
data1['start at (ms)'] = data1['start at (ms)'].str.strip()

# Function to convert timestamp string to datetime object
def convert_to_datetime(time_str):
    return datetime.strptime(time_str.strip(), '%H:%M:%S.%f')

# %%
def calculate_max_metrics(query_id, time_col, usage_col):
    # Chuyển đổi cột thời gian sang datetime nếu chưa chuyển
    data[time_col] = pd.to_datetime(data[time_col])
    data1['start at (ms)'] = pd.to_datetime(data1['start at (ms)'])
    
    # Lấy thời gian bắt đầu và duration của truy vấn từ data1
    query_start = data1.loc[data1['query'] == query_id, 'start at (ms)'].values[0]
    query_duration = data1.loc[data1['query'] == query_id, 'time (ms)'].values[0] 
    
    # Tính thời gian kết thúc của truy vấn (chuyển duration từ ms sang timedelta)
    query_end = query_start + pd.to_timedelta(int(query_duration), unit='ms')
    
    # Lọc các dòng trong data có thời gian nằm trong khoảng của truy vấn
    filtered_rows = data[(data[time_col] >= query_start) & (data[time_col] <= query_end)]
    if filtered_rows.empty and query_duration != 0:
        # Get timestamps before query_end
        before_end = data[data[time_col] <= query_end]
        if not before_end.empty:
            # Get the row with the maximum (latest) timestamp
            filtered_rows = before_end[before_end[time_col] == before_end[time_col].max()]
    if not filtered_rows.empty:
        max_usage = filtered_rows[usage_col].max()  # Changed from mean() to max()
        return max_usage
    else:
        return None

# %%
def process_query_metrics(query_id):
    # Ví dụ sử dụng:
    avg_cpu_usage = calculate_max_metrics(query_id, 'CPU_time(ms)', 'CPU_USAGE(%)')
    avg_gpu_usage = calculate_max_metrics(query_id, 'GPU_time(ms)', 'GPU_USAGE(%)')
    avg_ram_usage = calculate_max_metrics(query_id, 'RAM_time(ms)', 'RAM_USED(Gb)')
    avg_vram_usage = calculate_max_metrics(query_id, 'VRAM_time(ms)', 'VRAM_USED(Gb)')
    avg_power_usage = calculate_max_metrics(query_id, 'POWER_time(ms)', 'POWER_USE(W)')
    # Create a DataFrame with the required data
    query1_duration = data1.loc[data1['query'] == query_id, 'time (ms)'].values[0]
    new_data = pd.DataFrame({
        'query_id': [query_id],
        'time (ms)': [query1_duration],
        'avg_cpu_usage': [avg_cpu_usage],
        'avg_gpu_usage': [avg_gpu_usage],
        'avg_ram_usage': [avg_ram_usage],
        'avg_vram_usage': [avg_vram_usage],
        'avg_power_usage': [avg_power_usage]
    })
    
    try:
        # Try to read existing file
        existing_data = pd.read_csv(filename)
        # Append new data
        output_data = pd.concat([existing_data, new_data], ignore_index=True)
    except FileNotFoundError:
        # If file doesn't exist, use just the new data
        output_data = new_data
    # Save the DataFrame to a CSV file
    output_data.to_csv(filename, index=False)

    return new_data

# %%
# Process metrics for queries 1 through 10 using a loop
metrics_results = {}  # Dictionary to store results if needed

for i in range(1, query+1):
    query_id = f"query {i}"
    print(f"Processing {query_id}...")
    
    try:
        # Process the query metrics and store the result
        metrics_results[query_id] = process_query_metrics(query_id)
    except Exception as e:
        print(f"Error processing {query_id}: {e}")

print("All queries processed and appended to query_metrics.csv")
# Out:
# Processing query 1...
# Processing query 2...
# Processing query 3...
# Processing query 4...
# Processing query 5...
# Processing query 6...
# Processing query 7...
# Processing query 8...
# Processing query 9...
# Processing query 10...
# Processing query 11...
# Error processing query 11: invalid literal for int() with base 10: ' '
# Processing query 12...
# Processing query 13...
# Processing query 14...
# Error processing query 14: invalid literal for int() with base 10: ' '
# Processing query 15...
# Error processing query 15: invalid literal for int() with base 10: ' '
# Processing query 16...
# Processing query 17...
# Processing query 18...
# Processing query 19...
# Processing query 20...
# Processing query 21...
# Error processing query 21: invalid literal for int() with base 10: ' '
# Processing query 22...
# Processing query 23...
# Error processing query 23: index 0 is out of bounds for axis 0 with size 0
# Processing query 24...
# Error processing query 24: index 0 is out of bounds for axis 0 with size 0
# Processing query 25...
# Error processing query 25: index 0 is out of bounds for axis 0 with size 0
# Processing query 26...
# Error processing query 26: index 0 is out of bounds for axis 0 with size 0
# Processing query 27...
# Error processing query 27: index 0 is out of bounds for axis 0 with size 0
# Processing query 28...
# Error processing query 28: index 0 is out of bounds for axis 0 with size 0
# Processing query 29...
# Error processing query 29: index 0 is out of bounds for axis 0 with size 0
# Processing query 30...
# Error processing query 30: index 0 is out of bounds for axis 0 with size 0
# Processing query 31...
# Error processing query 31: index 0 is out of bounds for axis 0 with size 0
# Processing query 32...
# Error processing query 32: index 0 is out of bounds for axis 0 with size 0
# Processing query 33...
# Error processing query 33: index 0 is out of bounds for axis 0 with size 0
# Processing query 34...
# Error processing query 34: index 0 is out of bounds for axis 0 with size 0
# Processing query 35...
# Error processing query 35: index 0 is out of bounds for axis 0 with size 0
# Processing query 36...
# Error processing query 36: index 0 is out of bounds for axis 0 with size 0
# Processing query 37...
# Error processing query 37: index 0 is out of bounds for axis 0 with size 0
# Processing query 38...
# Error processing query 38: index 0 is out of bounds for axis 0 with size 0
# Processing query 39...
# Error processing query 39: index 0 is out of bounds for axis 0 with size 0
# Processing query 40...
# Error processing query 40: index 0 is out of bounds for axis 0 with size 0
# Processing query 41...
# Error processing query 41: index 0 is out of bounds for axis 0 with size 0
# Processing query 42...
# Error processing query 42: index 0 is out of bounds for axis 0 with size 0
# Processing query 43...
# Error processing query 43: index 0 is out of bounds for axis 0 with size 0
# Processing query 44...
# Error processing query 44: index 0 is out of bounds for axis 0 with size 0
# Processing query 45...
# Error processing query 45: index 0 is out of bounds for axis 0 with size 0
# Processing query 46...
# Error processing query 46: index 0 is out of bounds for axis 0 with size 0
# Processing query 47...
# Error processing query 47: index 0 is out of bounds for axis 0 with size 0
# Processing query 48...
# Error processing query 48: index 0 is out of bounds for axis 0 with size 0
# Processing query 49...
# Error processing query 49: index 0 is out of bounds for axis 0 with size 0
# Processing query 50...
# Error processing query 50: index 0 is out of bounds for axis 0 with size 0
# Processing query 51...
# Error processing query 51: index 0 is out of bounds for axis 0 with size 0
# Processing query 52...
# Error processing query 52: index 0 is out of bounds for axis 0 with size 0
# Processing query 53...
# Error processing query 53: index 0 is out of bounds for axis 0 with size 0
# Processing query 54...
# Error processing query 54: index 0 is out of bounds for axis 0 with size 0
# Processing query 55...
# Error processing query 55: index 0 is out of bounds for axis 0 with size 0
# Processing query 56...
# Error processing query 56: index 0 is out of bounds for axis 0 with size 0
# Processing query 57...
# Error processing query 57: index 0 is out of bounds for axis 0 with size 0
# Processing query 58...
# Error processing query 58: index 0 is out of bounds for axis 0 with size 0
# Processing query 59...
# Error processing query 59: index 0 is out of bounds for axis 0 with size 0
# Processing query 60...
# Error processing query 60: index 0 is out of bounds for axis 0 with size 0
# Processing query 61...
# Error processing query 61: index 0 is out of bounds for axis 0 with size 0
# Processing query 62...
# Error processing query 62: index 0 is out of bounds for axis 0 with size 0
# Processing query 63...
# Error processing query 63: index 0 is out of bounds for axis 0 with size 0
# Processing query 64...
# Error processing query 64: index 0 is out of bounds for axis 0 with size 0
# Processing query 65...
# Error processing query 65: index 0 is out of bounds for axis 0 with size 0
# Processing query 66...
# Error processing query 66: index 0 is out of bounds for axis 0 with size 0
# Processing query 67...
# Error processing query 67: index 0 is out of bounds for axis 0 with size 0
# Processing query 68...
# Error processing query 68: index 0 is out of bounds for axis 0 with size 0
# Processing query 69...
# Error processing query 69: index 0 is out of bounds for axis 0 with size 0
# Processing query 70...
# Error processing query 70: index 0 is out of bounds for axis 0 with size 0
# Processing query 71...
# Error processing query 71: index 0 is out of bounds for axis 0 with size 0
# Processing query 72...
# Error processing query 72: index 0 is out of bounds for axis 0 with size 0
# Processing query 73...
# Error processing query 73: index 0 is out of bounds for axis 0 with size 0
# Processing query 74...
# Error processing query 74: index 0 is out of bounds for axis 0 with size 0
# Processing query 75...
# Error processing query 75: index 0 is out of bounds for axis 0 with size 0
# Processing query 76...
# Error processing query 76: index 0 is out of bounds for axis 0 with size 0
# Processing query 77...
# Error processing query 77: index 0 is out of bounds for axis 0 with size 0
# Processing query 78...
# Error processing query 78: index 0 is out of bounds for axis 0 with size 0
# Processing query 79...
# Error processing query 79: index 0 is out of bounds for axis 0 with size 0
# Processing query 80...
# Error processing query 80: index 0 is out of bounds for axis 0 with size 0
# Processing query 81...
# Error processing query 81: index 0 is out of bounds for axis 0 with size 0
# Processing query 82...
# Error processing query 82: index 0 is out of bounds for axis 0 with size 0
# Processing query 83...
# Error processing query 83: index 0 is out of bounds for axis 0 with size 0
# Processing query 84...
# Error processing query 84: index 0 is out of bounds for axis 0 with size 0
# Processing query 85...
# Error processing query 85: index 0 is out of bounds for axis 0 with size 0
# Processing query 86...
# Error processing query 86: index 0 is out of bounds for axis 0 with size 0
# Processing query 87...
# Error processing query 87: index 0 is out of bounds for axis 0 with size 0
# Processing query 88...
# Error processing query 88: index 0 is out of bounds for axis 0 with size 0
# Processing query 89...
# Error processing query 89: index 0 is out of bounds for axis 0 with size 0
# Processing query 90...
# Error processing query 90: index 0 is out of bounds for axis 0 with size 0
# Processing query 91...
# Error processing query 91: index 0 is out of bounds for axis 0 with size 0
# Processing query 92...
# Error processing query 92: index 0 is out of bounds for axis 0 with size 0
# Processing query 93...
# Error processing query 93: index 0 is out of bounds for axis 0 with size 0
# Processing query 94...
# Error processing query 94: index 0 is out of bounds for axis 0 with size 0
# Processing query 95...
# Error processing query 95: index 0 is out of bounds for axis 0 with size 0
# Processing query 96...
# Error processing query 96: index 0 is out of bounds for axis 0 with size 0
# Processing query 97...
# Error processing query 97: index 0 is out of bounds for axis 0 with size 0
# Processing query 98...
# Error processing query 98: index 0 is out of bounds for axis 0 with size 0
# Processing query 99...
# Error processing query 99: index 0 is out of bounds for axis 0 with size 0
# All queries processed and appended to query_metrics.csv
